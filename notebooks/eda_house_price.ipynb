# %% [markdown]
# # EDA — House price (`house_price`)

# %%
from pathlib import Path
import sys
sys.path.insert(0, str(Path.cwd().resolve().parent))
from notebooks.run_eda import run_eda
run_eda("house_price")
