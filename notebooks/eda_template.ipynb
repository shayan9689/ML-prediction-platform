# %% [markdown]
# # EDA template — set TASK_ID and run
#
# Missing-value bar, numeric distributions, categorical counts, correlation, target balance.

# %%
from pathlib import Path
import sys
ROOT = Path.cwd().resolve().parent if Path.cwd().name == "notebooks" else Path.cwd().resolve()
sys.path.insert(0, str(ROOT))

TASK_ID = "house_price"  # churn | loan_default
DATA_PATH = None  # defaults to src.config path

from notebooks.run_eda import run_eda
summary = run_eda(TASK_ID)
summary
